# %% [markdown]
# ### Segmenting and clustering Neighborhoods in the city of Toronto, Canada

# %% [markdown]
# #### Week 3 - Assignment

# %% [markdown]
# This Jupyter contains my attempted solution to Question 1 of week 3 assignment in the Applied Capstone Module.

# %% [markdown]
# ##### Submitted by: Tevin RIchard

# %% [markdown]
# # Question 1

# %% [markdown]
# #### 1.1 Import the required libraries

# %%
import pandas as pd
import requests

# %% [markdown]
# #### 1.2. Extract the required data from the wikipedia page

# %%
url ="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

#save data to variable using the .get method

wikipedia_data = requests.get(url)

# %% [markdown]
# #### 1.3 Load the page html text data into a pandas dataframe

# %%
#using the .text method to pull the text data

table_data = pd.read_html(wikipedia_data.text)

print("The loaded data is a ", type(table_data), "with ", len(table_data), "elements")
# Out:
# The loaded data is a  <class 'list'> with  3 elements

# %%
# Take a look at the data
table_data
# Out:
# [    Postal Code           Borough  \
#  0           M1A      Not assigned
#  1           M2A      Not assigned
#  2           M3A        North York
#  3           M4A        North York
#  4           M5A  Downtown Toronto
#  ..          ...               ...
#  175         M5Z      Not assigned
#  176         M6Z      Not assigned
#  177         M7Z      Not assigned
#  178         M8Z         Etobicoke
#  179         M9Z      Not assigned
#
#                                           Neighbourhood
#  0                                         Not assigned
#  1                                         Not assigned
#  2                                            Parkwoods
#  3                                     Victoria Village
#  4                            Regent Park, Harbourfront
#  ..                                                 ...
#  175                                       Not assigned
#  176                                       Not assigned
# ...

# %% [markdown]
# #### 1.4 Extract the data required (First element in the list containing our three columns)

# %%
# replce the list with our required data since lists are mutable
table_data = table_data[0]
table_data
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# ...

# %% [markdown]
# #### 1.5 Drop all the Boroughs that contain Not Assigned elements

# %%
df = table_data[table_data["Borough"] != "Not assigned"]
df
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# ...

# %% [markdown]
# #### 1.6 Group all the elements that have the same postal codes as a single entry

# %%
df = df.groupby(['Postal Code']).head()
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# ...

# %% [markdown]
# #### 1.7.Fix the indices

# %%
# reset the dataframe index
df = df.reset_index()
df
# Out:
#      index Postal Code           Borough  \
# 0        0         M3A        North York
# 1        1         M4A        North York
# 2        2         M5A  Downtown Toronto
# 3        3         M6A        North York
# 4        4         M7A  Downtown Toronto
# ..     ...         ...               ...
# 98      98         M8X         Etobicoke
# 99      99         M4Y  Downtown Toronto
# 100    100         M7Y      East Toronto
# 101    101         M8Y         Etobicoke
# 102    102         M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# ...

# %%
# replace the old index with the updated indices
df = df.drop(["index"], "columns")
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# ...

# %% [markdown]
# #### 1.8 Get the shape of the data set

# %%
print("The data frame has ", df.shape[0], "rows and ", df.shape[1], "columns")
# Out:
# The data frame has  103 rows and  3 columns

# %% [markdown]
# # This is the end of Question 1 of my assignment
